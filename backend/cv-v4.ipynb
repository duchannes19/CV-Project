# %%
# Importing necessary libraries
import os
import numpy as np
import cv2
from pathlib import Path
import SimpleITK as sitk
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy.ndimage import zoom, shift, rotate, map_coordinates, gaussian_filter
from skimage.transform import resize
import zipfile
import gdown

from tensorflow.keras import layers, models, Input, regularizers, optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.metrics import MeanIoU

# Ensure TensorFlow is using GPU if available
print(f"Using TensorFlow version: {tf.__version__}")
print(f"Num GPUs Available: {len(tf.config.list_physical_devices('GPU'))}")
# Out:
# Using TensorFlow version: 2.16.1
# Num GPUs Available: 0

# %%
main_path = Path.cwd()  # Get the current working directory

# Create the datasets folder if it doesn't exist
if not os.path.exists(main_path / 'datasets'):
    os.mkdir(main_path / 'datasets')

if not os.path.exists(main_path / 'datasets' / 'train') or not os.path.exists(main_path / 'datasets' / 'test'):
    
    # Download the dataset (zip)

    url = 'https://drive.google.com/file/d/1F9LFHyKA00G7aGNpF61D8GWeG54KiEam/view?usp=sharing'

    output = 'datasets/dataset.zip'

    gdown.download(url, output, quiet=False, fuzzy=True)

    # Unzip the dataset inside the datasets folder

    with zipfile.ZipFile(output, 'r') as zip_ref:
        zip_ref.extractall(main_path / 'datasets')

    print('Dataset unzipped successfully!')
    
    # Remove the zip file
    os.remove(output)
    
    # Then also download
    
    url = 'https://drive.google.com/file/d/17fKi5QYROdVoUjmzC90TCe_Tal9hNPph/view?usp=sharing'
    
    output = 'datasets/prostatex.zip'
    
    gdown.download(url, output, quiet=False, fuzzy=True)
    
    # Unzip the dataset inside the datasets folder
    
    with zipfile.ZipFile(output, 'r') as zip_ref:
        zip_ref.extractall(main_path / 'datasets')
    
    print('ProstateX dataset unzipped successfully!')
    
    # Remove the zip file
    
    os.remove(output)
else:
    print('Dataset already exists!')
# Out:
# Dataset already exists!

# %%
def load_mhd_image(image_path):
    """
    Loads a MetaImage (.mhd) file and returns it as a NumPy array.
    
    Args:
        image_path (Path): Path to the .mhd file.
    
    Returns:
        np.ndarray: 3D image array with shape (z, y, x).
    """
    try:
        image_sitk = sitk.ReadImage(str(image_path))
        image_np = sitk.GetArrayFromImage(image_sitk)  # Shape: (z, y, x)
        return image_np
    except Exception as e:
        print(f"[Loader] Error loading image {image_path.name}: {e}")
        return None

def load_mhd_mask(mask_path):
    """
    Loads a MetaImage (.mhd) file for the segmentation mask and returns it as a NumPy array.
    
    Args:
        mask_path (Path): Path to the mask .mhd file.
    
    Returns:
        np.ndarray: 3D mask array with shape (z, y, x), binary (0 and 1).
    """
    try:
        mask_sitk = sitk.ReadImage(str(mask_path))
        mask_np = sitk.GetArrayFromImage(mask_sitk)
        # Binarize the mask in case of any anomalies
        mask_np = (mask_np > 0).astype(np.float32)
        return mask_np
    except Exception as e:
        print(f"[Loader] Error loading mask {mask_path.name}: {e}")
        return None

# %%
def visualize_mri_and_mask(image, mask, slice_idx=None):
    """
    Visualizes a single slice of the MRI image and its corresponding mask.
    
    Args:
        image (np.ndarray): 3D MRI image array with shape (z, y, x).
        mask (np.ndarray): 3D mask array with shape (z, y, x).
        slice_idx (int, optional): Specific slice index to visualize. Defaults to the middle slice.
    """
    if slice_idx is None:
        slice_idx = image.shape[0] // 2  # Middle slice
    
    image_slice = image[slice_idx]
    mask_slice = mask[slice_idx]
    
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1, 2, 1)
    plt.imshow(image_slice, cmap='gray')
    plt.title(f'MRI Slice {slice_idx}')
    plt.axis('off')
    
    plt.subplot(1, 2, 2)
    plt.imshow(mask_slice, cmap='gray')
    plt.title(f'Mask Slice {slice_idx}')
    plt.axis('off')
    
    plt.show()

# %%
def resample_image_and_mask(image_path, mask_path, new_spacing=(1.0, 1.0, 1.0)):
    """
    Resamples the image and mask to the desired voxel spacing.
    
    Args:
        image_path (Path): Path to the MRI .mhd file.
        mask_path (Path): Path to the mask .mhd file.
        new_spacing (tuple): Desired voxel spacing (z, y, x) in mm.
    
    Returns:
        tuple: Resampled image and mask as NumPy arrays.
    """
    try:
        # Read the image and mask using SimpleITK
        image_sitk = sitk.ReadImage(str(image_path))
        mask_sitk = sitk.ReadImage(str(mask_path))
        
        original_spacing = image_sitk.GetSpacing()
        original_size = image_sitk.GetSize()
        #print(f"[Resample] Original spacing: {original_spacing}, size: {original_size}")
    
        # Calculate the new size based on the new spacing
        new_size = [
            int(np.round(original_size[i] * (original_spacing[i] / new_spacing[i])))
            for i in range(3)
        ]
        #print(f"[Resample] New spacing: {new_spacing}, new size: {new_size}")
    
        # Resample image
        resample_image = sitk.Resample(
            image_sitk,
            new_size,
            sitk.Transform(),
            sitk.sitkLinear,
            image_sitk.GetOrigin(),
            new_spacing,
            image_sitk.GetDirection(),
            0,
            image_sitk.GetPixelID()
        )
    
        # Resample mask with nearest neighbor to preserve labels
        resample_mask = sitk.Resample(
            mask_sitk,
            new_size,
            sitk.Transform(),
            sitk.sitkNearestNeighbor,
            mask_sitk.GetOrigin(),
            new_spacing,
            mask_sitk.GetDirection(),
            0,
            mask_sitk.GetPixelID()
        )
    
        # Convert to NumPy arrays
        image_np = sitk.GetArrayFromImage(resample_image).astype(np.float32)
        mask_np = sitk.GetArrayFromImage(resample_mask).astype(np.float32)
        mask_np = (mask_np > 0).astype(np.float32)  # Ensure binary mask
    
        return image_np, mask_np
    except Exception as e:
        print(f"[Resample] Error resampling {image_path.name}: {e}")
        return None, None

# %%
def normalize_image(image):
    """
    Normalizes the image to have zero mean and unit variance.
    
    Args:
        image (np.ndarray): 3D image array.
    
    Returns:
        np.ndarray: Normalized image.
    """
    mean = np.mean(image)
    std = np.std(image)
    normalized_image = (image - mean) / (std + 1e-8)
    return normalized_image

# %%
def preprocess_case_2d(image_path, mask_path, new_spacing=(1.0, 1.0, 1.0)):
    """
    Preprocesses a single case for 2D processing: resampling, normalization, and mask binarization.

    Args:
        image_path (Path): Path to the MRI .mhd file.
        mask_path (Path): Path to the mask .mhd file.
        new_spacing (tuple): Desired voxel spacing (z, y, x) in mm.

    Returns:
        tuple: Preprocessed 3D image and mask as NumPy arrays.
    """
    # Resample the 3D image and mask
    image, mask = resample_image_and_mask(image_path, mask_path, new_spacing=new_spacing)
    if image is None or mask is None:
        return None, None

    # Normalize the image
    image = normalize_image(image)

    return image, mask

# %%
import re

# Define the path to your dataset
data_dir = Path("datasets/train")  # Update this path as needed

# Regex for non-segmentation files, there is no "_segmentation" in the filename
regex = re.compile(r"^(?!.*_segmentation).*\.mhd$", re.IGNORECASE)

# Select an example case, a CaseXX.mhd file and its corresponding CaseXX_segmentation.mhd file
example_case = None
example_mask = None

# Find the example case and mask
for case_file in data_dir.glob("*.mhd"):
    if regex.match(case_file.name):
        example_case = case_file
        example_mask = data_dir / f"{case_file.stem}_segmentation.mhd"
        break

# Load the image and mask
image = load_mhd_image(example_case)
mask = load_mhd_mask(example_mask)

# Visualize the loaded image and mask
visualize_mri_and_mask(image, mask)

# %%
def extract_slices(image, mask):
    """
    Extracts 2D slices from a 3D image and mask.

    Args:
        image (np.ndarray): 3D image array with shape (z, y, x).
        mask (np.ndarray): 3D mask array with shape (z, y, x).

    Yields:
        tuple: (image_slice, mask_slice) as NumPy arrays.
    """
    z, y, x = image.shape

    for slice_idx in range(z):
        image_slice = image[slice_idx, :, :]
        mask_slice = mask[slice_idx, :, :]

        yield image_slice, mask_slice
        

def calculate_steps_2d(data_dir, dataset_type, patch_depth, patch_size):
    """
    Calculates the total number of patches for a given dataset split.

    Args:
        data_dir (Path): Path to the dataset directory.
        dataset_type (str): 'train' or 'test'.
        patch_depth (int): Number of slices per patch.
        patch_size (tuple): Desired (height, width) of each patch.

    Returns:
        int: Total number of patches.
    """
    case_paths = sorted((data_dir / dataset_type).glob("Case*.mhd"))
    total_patches = 0
    for case_path in case_paths:
        mask_path = case_path.parent / (case_path.stem + "_segmentation.mhd")
        if not mask_path.exists():
            continue
        image, mask = preprocess_case_2d(case_path, mask_path)
        if image is None or mask is None:
            continue
        patches = list(extract_slices(image, mask))
        total_patches += len(patches)
    return total_patches

# %%
def random_brightness_contrast_2d(image, mask, brightness_range=(0.8, 1.2), contrast_range=(0.8, 1.2)):
    """
    Randomly adjusts brightness and contrast of a 2D image.
    
    Args:
        image (np.ndarray): 2D image array.
        mask (np.ndarray): 2D mask array.
        brightness_range (tuple): Range for brightness adjustment.
        contrast_range (tuple): Range for contrast adjustment.
    
    Returns:
        tuple: Adjusted image and unchanged mask.
    """
    brightness = np.random.uniform(*brightness_range)
    contrast = np.random.uniform(*contrast_range)
    #print(f"[Augmentation] 2D Brightness: {brightness}, Contrast: {contrast}")
    
    image = image * brightness
    image = (image - np.mean(image)) * contrast + np.mean(image)
    image = np.clip(image, 0, 1)
    
    return image, mask

def random_affine_transform_2d(image, mask, rotation_range=(-10, 10), translation_range=(-5, 5), shear_range=(-5, 5), zoom_range=(0.9, 1.1)):
    """
    Applies random affine transformations to a 2D image and mask.
    
    Args:
        image (np.ndarray): 2D image array.
        mask (np.ndarray): 2D mask array.
        rotation_range (tuple): Range of rotation angles in degrees.
        translation_range (tuple): Range for horizontal and vertical translations.
        shear_range (tuple): Shear angle range in degrees.
        zoom_range (tuple): Range for zoom.
    
    Returns:
        tuple: Transformed image and mask.
    """
    angle = np.random.uniform(*rotation_range)
    tx = np.random.uniform(*translation_range)
    ty = np.random.uniform(*translation_range)
    shear = np.random.uniform(*shear_range)
    zoom = np.random.uniform(*zoom_range)
    
    #print(f"[Augmentation] 2D Affine Transform - Angle: {angle}, Tx: {tx}, Ty: {ty}, Shear: {shear}, Zoom: {zoom}")
    
    # Build the affine transformation matrix
    affine_matrix = cv2.getRotationMatrix2D(center=(image.shape[1]/2, image.shape[0]/2), angle=angle, scale=zoom)
    affine_matrix[0, 2] += tx
    affine_matrix[1, 2] += ty
    
    # Apply affine transformation
    image_transformed = cv2.warpAffine(image, affine_matrix, (image.shape[1], image.shape[0]), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT)
    mask_transformed = cv2.warpAffine(mask, affine_matrix, (mask.shape[1], mask.shape[0]), flags=cv2.INTER_NEAREST, borderMode=cv2.BORDER_REFLECT)
    
    return image_transformed, mask_transformed


def random_zoom_2d(image, mask, zoom_range=(0.9, 1.1)):
    """
    Applies a random zoom to a 2D image and mask.

    Args:
        image (np.ndarray): 2D image array.
        mask (np.ndarray): 2D mask array.
        zoom_range (tuple): Tuple specifying the zoom range.

    Returns:
        tuple: Zoomed image and mask.
    """
    # Choose a random zoom factor
    zoom_factor = np.random.uniform(zoom_range[0], zoom_range[1])
    #print(f"[Augmentation] 2D Zoom factor: {zoom_factor}")

    # Apply zoom to image
    image_zoomed = zoom(image, zoom=zoom_factor, order=1, mode='nearest')
    # Apply zoom to mask with nearest interpolation
    mask_zoomed = zoom(mask, zoom=zoom_factor, order=0, mode='nearest')

    # Crop or pad to original shape
    image_zoomed = crop_or_pad_2d(image_zoomed, image.shape)
    mask_zoomed = crop_or_pad_2d(mask_zoomed, mask.shape)

    return image_zoomed, mask_zoomed

def random_shift_2d(image, mask, shift_range=10):
    """
    Applies a random shift to a 2D image and mask.

    Args:
        image (np.ndarray): 2D image array.
        mask (np.ndarray): 2D mask array.
        shift_range (int): Maximum number of pixels to shift.

    Returns:
        tuple: Shifted image and mask.
    """
    # Generate random shifts for each axis
    shifts = np.random.uniform(-shift_range, shift_range, size=2)
    #print(f"[Augmentation] 2D Shifts: {shifts}")

    # Apply shift to image
    image_shifted = shift(image, shift=shifts, order=1, mode='nearest')
    # Apply shift to mask with nearest interpolation
    mask_shifted = shift(mask, shift=shifts, order=0, mode='nearest')

    return image_shifted, mask_shifted

def elastic_transform_2d(image, mask, alpha=1000, sigma=50):
    """
    Applies an elastic deformation to a 2D image and mask.

    Args:
        image (np.ndarray): 2D image array.
        mask (np.ndarray): 2D mask array.
        alpha (float): Scaling factor for intensity of deformation.
        sigma (float): Standard deviation for Gaussian filter.

    Returns:
        tuple: Elastically transformed image and mask.
    """
    random_state = np.random.RandomState(None)

    shape = image.shape
    #print(f"[Augmentation] 2D Elastic transform with alpha={alpha}, sigma={sigma}")

    # Generate random displacement fields
    dx = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma, mode="constant", cval=0) * alpha
    dy = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma, mode="constant", cval=0) * alpha

    # Create meshgrid
    y, x = np.meshgrid(np.arange(shape[0]), np.arange(shape[1]), indexing='ij')

    # Apply displacements
    indices = (y + dy, x + dx)

    # Map coordinates
    image_transformed = map_coordinates(image, indices, order=1, mode='nearest')
    mask_transformed = map_coordinates(mask, indices, order=0, mode='nearest')

    return image_transformed, mask_transformed

def add_gaussian_noise_2d(image, mask, mean=0, std=0.01):
    """
    Adds Gaussian noise to a 2D image.

    Args:
        image (np.ndarray): 2D image array.
        mask (np.ndarray): 2D mask array.
        mean (float): Mean of the Gaussian noise.
        std (float): Standard deviation of the Gaussian noise.

    Returns:
        tuple: Noisy image and unchanged mask.
    """
    #print(f"[Augmentation] Adding 2D Gaussian noise with mean={mean}, std={std}")
    noise = np.random.normal(mean, std, image.shape)
    image_noisy = image + noise
    image_noisy = np.clip(image_noisy, 0, 1)  # Ensure values are still in [0, 1]
    return image_noisy, mask

def random_rotation_2d(image, mask, angle_range=(-15, 15)):
    """
    Applies a random rotation to a 2D image and mask.

    Args:
        image (np.ndarray): 2D image array.
        mask (np.ndarray): 2D mask array.
        angle_range (tuple): Range of angles for rotation in degrees.

    Returns:
        tuple: Rotated image and mask.
    """
    angle = np.random.uniform(angle_range[0], angle_range[1])
    #print(f"[Augmentation] 2D Rotation angle: {angle} degrees")

    # Rotate image
    image_rotated = rotate(image, angle, reshape=False, order=1, mode='nearest')
    # Rotate mask with nearest interpolation
    mask_rotated = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    return image_rotated, mask_rotated

def random_flip_2d(image, mask):
    """
    Applies random flipping along horizontal and vertical axes to a 2D image and mask.

    Args:
        image (np.ndarray): 2D image array.
        mask (np.ndarray): 2D mask array.

    Returns:
        tuple: Flipped or unchanged image and mask.
    """
    # Horizontal flip
    if np.random.rand() > 0.5:
        #print(f"[Augmentation] 2D Horizontal flipping")
        image = np.fliplr(image)
        mask = np.fliplr(mask)

    # Vertical flip
    if np.random.rand() > 0.5:
        #print(f"[Augmentation] 2D Vertical flipping")
        image = np.flipud(image)
        mask = np.flipud(mask)

    return image, mask

def crop_or_pad_2d(image, target_shape):
    """
    Crops or pads a 2D image to match the target shape.

    Args:
        image (np.ndarray): 2D image to be resized.
        target_shape (tuple): Desired shape (height, width).

    Returns:
        np.ndarray: Resized image.
    """
    current_shape = image.shape
    padding = []
    cropping = []
    for i in range(2):  # y, x
        if current_shape[i] < target_shape[i]:
            total_pad = target_shape[i] - current_shape[i]
            pad_before = total_pad // 2
            pad_after = total_pad - pad_before
            padding.append((pad_before, pad_after))
            cropping.append((0, current_shape[i]))
        elif current_shape[i] > target_shape[i]:
            total_crop = current_shape[i] - target_shape[i]
            crop_before = total_crop // 2
            crop_after = crop_before + target_shape[i]
            cropping.append((crop_before, crop_after))
            padding.append((0, 0))
        else:
            cropping.append((0, current_shape[i]))
            padding.append((0, 0))

    # Crop
    y_min, y_max = cropping[0]
    x_min, x_max = cropping[1]
    image_cropped = image[y_min:y_max, x_min:x_max]

    # Pad
    y_pad, x_pad = padding
    image_padded = np.pad(
        image_cropped,
        ((y_pad[0], y_pad[1]),
         (x_pad[0], x_pad[1])),
        mode='constant',
        constant_values=0
    )

    return image_padded


def augment_data_2d(image, mask, augmentations):
    """
    Applies a series of augmentations to a 2D image and mask.
    
    Args:
        image (np.ndarray): 2D image array.
        mask (np.ndarray): 2D mask array.
        augmentations (dict): Dictionary specifying which augmentations to apply and their parameters.
    
    Returns:
        tuple: Augmented image and mask.
    """
    # Random Zoom
    if augmentations.get('zoom', False):
        image, mask = random_zoom_2d(image, mask, zoom_range=augmentations.get('zoom_range', (0.9, 1.1)))

    # Random Shift
    if augmentations.get('shift', False):
        image, mask = random_shift_2d(image, mask, shift_range=augmentations.get('shift_range', 10))

    # Elastic Transformation
    if augmentations.get('elastic', False):
        image, mask = elastic_transform_2d(image, mask,
                                           alpha=augmentations.get('elastic_alpha', 1000),
                                           sigma=augmentations.get('elastic_sigma', 50))

    # Adding Gaussian Noise
    if augmentations.get('noise', False):
        image, mask = add_gaussian_noise_2d(image, mask,
                                           mean=augmentations.get('noise_mean', 0),
                                           std=augmentations.get('noise_std', 0.01))

    # Random Rotation
    if augmentations.get('rotation', False):
        image, mask = random_rotation_2d(image, mask, angle_range=augmentations.get('rotation_range', (-15, 15)))

    # Random Flipping
    if augmentations.get('flip', False):
        image, mask = random_flip_2d(image, mask)

    # Random Brightness and Contrast
    if augmentations.get('brightness_contrast', False):
        image, mask = random_brightness_contrast_2d(image, mask,
                                                   brightness_range=augmentations.get('brightness_range', (0.8, 1.2)),
                                                   contrast_range=augmentations.get('contrast_range', (0.8, 1.2)))

    # Random Affine Transformation
    #if augmentations.get('affine', False):
    #    image, mask = random_affine_transform_2d(image, mask,
    #                                             rotation_range=augmentations.get('affine_rotation_range', (-10, 10)),
    #                                             translation_range=augmentations.get('affine_translation_range', (-5, 5)),
    #                                             shear_range=augmentations.get('affine_shear_range', (-5, 5)),
    #                                             zoom_range=augmentations.get('affine_zoom_range', (0.9, 1.1)))

    return image, mask

# %% [markdown]
# ### PROSTATEX

# %%
import SimpleITK as sitk
import numpy as np
import os
import matplotlib.pyplot as plt
import cv2
import re
from pathlib import Path

# Configuration
BASE_SEGMENTATION_DIR = Path("datasets/old/segmentation/PROSTATEx")
BASE_IMAGES_DIR = Path("datasets/old/segmentation2/PROSTATEx")
SEGMENTATION_FILENAME = "1-1.dcm"
IMAGE_FILENAME_PATTERN = r".*\.dcm$"
IMG_HEIGHT, IMG_WIDTH = 128, 128
TARGET_DEPTH = 16

def pad_or_crop_volume(volume, target_depth):
    current_depth = volume.shape[0]
    if current_depth == target_depth:
        return volume
    elif current_depth > target_depth:
        start = (current_depth - target_depth) // 2
        return volume[start:start+target_depth]
    else:
        diff = target_depth - current_depth
        pad_before = diff // 2
        pad_after = diff - pad_before
        return np.pad(volume, ((pad_before, pad_after), (0,0), (0,0)), mode='constant')

def load_sitk_volume_from_directory(directory, filename_pattern=None):
    reader = sitk.ImageSeriesReader()
    if filename_pattern:
        all_files = [os.path.join(directory, f) for f in os.listdir(directory)]
        filtered_files = [f for f in all_files if re.match(filename_pattern, os.path.basename(f))]
        if not filtered_files:
            return None
        reader.SetFileNames(filtered_files)
    else:
        dicom_files = reader.GetGDCMSeriesFileNames(str(directory))
        if not dicom_files:
            return None
        reader.SetFileNames(dicom_files)
    
    image = reader.Execute()
    return sitk.GetArrayFromImage(image)

def load_sitk_image(filepath):
    if not filepath.exists():
        return None
    image = sitk.ReadImage(str(filepath))
    return sitk.GetArrayFromImage(image)

def load_dataset(segmentation_dir, images_dir, segmentation_filename, img_height, img_width, target_depth):
    images = []
    masks = []
    
    patients = [p for p in segmentation_dir.iterdir() if p.is_dir()]
    print(f"Found {len(patients)} patients")

    for patient_dir in patients:
        patient = patient_dir.name
        mask_path = patient_dir / segmentation_filename
        
        # Load segmentation mask
        mask_volume = load_sitk_image(mask_path)
        if mask_volume is None:
            print(f"Mask load failed: {patient}")
            continue
            
        # Ensure 3D format
        if mask_volume.ndim == 2:
            mask_volume = np.expand_dims(mask_volume, 0)

        # Load image volume
        patient_img_dir = images_dir / patient
        if not patient_img_dir.exists():
            print(f"Image dir missing: {patient}")
            continue
            
        img_volume = load_sitk_volume_from_directory(patient_img_dir, IMAGE_FILENAME_PATTERN)
        if img_volume is None:
            print(f"Image load failed: {patient}")
            continue

        # Process volumes
        img_volume = pad_or_crop_volume(img_volume, target_depth)
        mask_volume = pad_or_crop_volume(mask_volume, target_depth)

        # Process each slice
        for slice_idx in range(target_depth):
            img_slice = cv2.resize(img_volume[slice_idx], (img_width, img_height), 
                                 interpolation=cv2.INTER_LINEAR)
            mask_slice = cv2.resize(mask_volume[slice_idx], (img_width, img_height),
                                  interpolation=cv2.INTER_NEAREST)
            
            # Binarize and store
            images.append(img_slice)
            masks.append((mask_slice > 0.5).astype(np.uint8))

        print(f"Processed {target_depth} slices from {patient}")

    return np.array(images), np.array(masks)

def prostatex():
    images, masks = load_dataset(
        segmentation_dir=BASE_SEGMENTATION_DIR,
        images_dir=BASE_IMAGES_DIR,
        segmentation_filename=SEGMENTATION_FILENAME,
        img_height=IMG_HEIGHT,
        img_width=IMG_WIDTH,
        target_depth=TARGET_DEPTH
    )

    print("\nDataset Summary:")
    print(f"Total slices: {images.shape[0]}")
    print(f"Image shape: {images.shape[1:]} (height, width)")
    print(f"Mask shape: {masks.shape[1:]} (height, width)")
    
    return images, masks

prostatex_images, prostatex_masks = prostatex()
# Out:
# Found 66 patients
# Processed 16 slices from ProstateX-0004
# Processed 16 slices from ProstateX-0007
# Processed 16 slices from ProstateX-0009
# Processed 16 slices from ProstateX-0015
# Processed 16 slices from ProstateX-0020
# Processed 16 slices from ProstateX-0026
# Processed 16 slices from ProstateX-0046
# Processed 16 slices from ProstateX-0054
# Processed 16 slices from ProstateX-0056
# Processed 16 slices from ProstateX-0065
# Processed 16 slices from ProstateX-0066
# Processed 16 slices from ProstateX-0069
# Processed 16 slices from ProstateX-0070
# Processed 16 slices from ProstateX-0072
# Processed 16 slices from ProstateX-0076
# Processed 16 slices from ProstateX-0083
# Processed 16 slices from ProstateX-0084
# Processed 16 slices from ProstateX-0089
# Processed 16 slices from ProstateX-0090
# Processed 16 slices from ProstateX-0094
# Processed 16 slices from ProstateX-0096
# Processed 16 slices from ProstateX-0102
# Processed 16 slices from ProstateX-0111
# Processed 16 slices from ProstateX-0112
# Processed 16 slices from ProstateX-0117
# Processed 16 slices from ProstateX-0118
# Processed 16 slices from ProstateX-0121
# Processed 16 slices from ProstateX-0125
# Processed 16 slices from ProstateX-0129
# Processed 16 slices from ProstateX-0130
# Processed 16 slices from ProstateX-0134
# Processed 16 slices from ProstateX-0136
# Processed 16 slices from ProstateX-0141
# Processed 16 slices from ProstateX-0142
# Processed 16 slices from ProstateX-0144
# Processed 16 slices from ProstateX-0150
# Processed 16 slices from ProstateX-0156
# Processed 16 slices from ProstateX-0161
# Processed 16 slices from ProstateX-0168
# Processed 16 slices from ProstateX-0170
# Processed 16 slices from ProstateX-0176
# Processed 16 slices from ProstateX-0177
# Processed 16 slices from ProstateX-0182
# Processed 16 slices from ProstateX-0183
# Processed 16 slices from ProstateX-0184
# Processed 16 slices from ProstateX-0188
# Processed 16 slices from ProstateX-0193
# Processed 16 slices from ProstateX-0196
# Processed 16 slices from ProstateX-0198
# Processed 16 slices from ProstateX-0201
# Processed 16 slices from ProstateX-0209
# Processed 16 slices from ProstateX-0217
# Processed 16 slices from ProstateX-0219
# Processed 16 slices from ProstateX-0234
# Processed 16 slices from ProstateX-0241
# Processed 16 slices from ProstateX-0244
# Processed 16 slices from ProstateX-0249
# Processed 16 slices from ProstateX-0254
# Processed 16 slices from ProstateX-0265
# Processed 16 slices from ProstateX-0275
# Processed 16 slices from ProstateX-0297
# Processed 16 slices from ProstateX-0309
# Processed 16 slices from ProstateX-0311
# Processed 16 slices from ProstateX-0323
# Processed 16 slices from ProstateX-0334
# Processed 16 slices from ProstateX-0340
#
# Dataset Summary:
# Total slices: 1056
# Image shape: (128, 128) (height, width)
# Mask shape: (128, 128) (height, width)

# %%
import matplotlib.pyplot as plt

# Visualize the first image and mask

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(prostatex_images[0], cmap='gray')
plt.axis('off')
plt.title("Image")
plt.subplot(1, 2, 2)
plt.imshow(prostatex_masks[0], cmap='gray')
plt.axis('off')
plt.title("Mask")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### END OF PROSTATEX

# %%
def dataset_generator_2d(data_dir, batch_size, patch_size=(128, 128), dataset_type='train', 
                        augmentations=None, prostatex_data=None):
    """
    Modified generator to include PROSTATEx data with consistent preprocessing.
    """
    # Load original cases
    case_paths = sorted((data_dir / dataset_type).glob("Case*.mhd"))
    
    # Prepare PROSTATEx data if provided
    prostatex_slices = []
    if prostatex_data is not None:
        px_images, px_masks = prostatex_data
        # Normalize and cast to float32
        px_images = ((px_images - px_images.min()) / 
                    (px_images.max() - px_images.min())).astype(np.float32)
        px_masks = px_masks.astype(np.float32)
        # Add channel dimension
        px_images = np.expand_dims(px_images, -1)
        px_masks = np.expand_dims(px_masks, -1)
        prostatex_slices = list(zip(px_images, px_masks))

    while True:
        # Combine both data sources
        all_items = [(p, 'case') for p in case_paths] + [(s, 'slice') for s in prostatex_slices]
        
        if dataset_type == 'train':
            np.random.shuffle(all_items)

        image_batch = []
        mask_batch = []

        for item in all_items:
            data, data_type = item

            if data_type == 'case':
                # Original processing pipeline
                segmentation_path = data.parent / (data.stem + "_segmentation.mhd")
                if not segmentation_path.exists():
                    continue

                image, mask = preprocess_case_2d(data, segmentation_path)
                if image is None or mask is None:
                    continue

                for img_slice, msk_slice in extract_slices(image, mask):
                    if augmentations and dataset_type == 'train':
                        img_slice, msk_slice = augment_data_2d(img_slice, msk_slice, augmentations)
                    
                    img_slice = crop_or_pad_2d(img_slice, patch_size)
                    msk_slice = crop_or_pad_2d(msk_slice, patch_size)
                    
                    img_slice = np.expand_dims(img_slice, -1)
                    msk_slice = np.expand_dims(msk_slice, -1)
                    
                    image_batch.append(img_slice)
                    mask_batch.append(msk_slice)

                    if len(image_batch) == batch_size:
                        yield np.array(image_batch), np.array(mask_batch)
                        image_batch = []
                        mask_batch = []

            elif data_type == 'slice':
                # PROSTATEx slice processing
                img_slice, msk_slice = data
                
                # Apply augmentations
                if augmentations and dataset_type == 'train':
                    img_aug, msk_aug = augment_data_2d(
                        img_slice[...,0], msk_slice[...,0], augmentations
                    )
                else:
                    img_aug, msk_aug = img_slice[...,0], msk_slice[...,0]

                # Ensure correct dimensions
                img_aug = np.expand_dims(img_aug, -1)
                msk_aug = np.expand_dims(msk_aug, -1)

                image_batch.append(img_aug)
                mask_batch.append(msk_aug)

                if len(image_batch) == batch_size:
                    yield np.array(image_batch), np.array(mask_batch)
                    image_batch = []
                    mask_batch = []

        # Yield remaining samples
        if len(image_batch) > 0:
            yield np.array(image_batch), np.array(mask_batch)

# %%
def residual_block_2d_spatial_dropout(input_tensor, filters, dropout_rate=0.2, l2_reg=1e-5):
    """
    Create a residual block for the 2D segmentation model with Spatial Dropout.
    
    Args:
        input_tensor (tf.Tensor): Input tensor.
        filters (int): Number of filters for the convolutional layers.
        dropout_rate (float): Dropout rate for regularization.
        l2_reg (float): L2 regularization factor.
    
    Returns:
        tf.Tensor: Output tensor after applying the residual block.
    """
    reg = regularizers.l2(l2_reg)

    # First convolution
    x = layers.Conv2D(filters, kernel_size=(3, 3), padding="same", kernel_regularizer=reg)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Second convolution
    x = layers.Conv2D(filters, kernel_size=(3, 3), padding="same", kernel_regularizer=reg)(x)
    x = layers.BatchNormalization()(x)

    # Projection shortcut if input and output shapes differ
    if input_tensor.shape[-1] != filters:
        input_tensor = layers.Conv2D(filters, kernel_size=(1, 1), padding="same", kernel_regularizer=reg)(input_tensor)
        input_tensor = layers.BatchNormalization()(input_tensor)

    # Add skip connection
    x = layers.add([x, input_tensor])
    x = layers.ReLU()(x)

    # Add Spatial Dropout
    x = layers.SpatialDropout2D(dropout_rate)(x)
    return x


def build_residual_2d_unet_spatial_dropout(input_shape=(128, 128, 1), dropout_rate=0.2, l2_reg=1e-5):
    """
    Build a residual-based 2D U-Net segmentation model with Spatial Dropout.
    
    Args:
        input_shape (tuple): Shape of the input data (height, width, channels).
        dropout_rate (float): Dropout rate for regularization.
        l2_reg (float): L2 regularization factor.
    
    Returns:
        tf.keras.Model: Compiled 2D U-Net model with Spatial Dropout.
    """
    inputs = Input(shape=input_shape)
    print(f"[Model_2D_SpatialDropout] Input shape: {inputs.shape}")

    # Encoder
    c1 = layers.Conv2D(16, kernel_size=(3, 3), padding="same", kernel_regularizer=regularizers.l2(l2_reg))(inputs)
    c1 = residual_block_2d_spatial_dropout(c1, filters=16, dropout_rate=dropout_rate, l2_reg=l2_reg)
    p1 = layers.MaxPooling2D(pool_size=(2, 2))(c1)   # (64x64x16)

    c2 = residual_block_2d_spatial_dropout(p1, filters=32, dropout_rate=dropout_rate, l2_reg=l2_reg)
    p2 = layers.MaxPooling2D(pool_size=(2, 2))(c2)   # (32x32x32)

    c3 = residual_block_2d_spatial_dropout(p2, filters=64, dropout_rate=dropout_rate, l2_reg=l2_reg)
    p3 = layers.MaxPooling2D(pool_size=(2, 2))(c3)   # (16x16x64)

    # Bottleneck
    c4 = residual_block_2d_spatial_dropout(p3, filters=128, dropout_rate=dropout_rate, l2_reg=l2_reg)
    print(f"[Model_2D_SpatialDropout] Bottleneck shape: {c4.shape}")

    # Decoder
    u3 = layers.Conv2DTranspose(64, kernel_size=(2, 2), strides=(2, 2), padding="same")(c4)
    u3 = layers.concatenate([u3, c3])
    c5 = residual_block_2d_spatial_dropout(u3, filters=64, dropout_rate=dropout_rate, l2_reg=l2_reg) # (32x32x64)

    u2 = layers.Conv2DTranspose(32, kernel_size=(2, 2), strides=(2, 2), padding="same")(c5)
    u2 = layers.concatenate([u2, c2])
    c6 = residual_block_2d_spatial_dropout(u2, filters=32, dropout_rate=dropout_rate, l2_reg=l2_reg) # (64x64x32)

    u1 = layers.Conv2DTranspose(16, kernel_size=(2, 2), strides=(2, 2), padding="same")(c6)
    u1 = layers.concatenate([u1, c1])
    c7 = residual_block_2d_spatial_dropout(u1, filters=16, dropout_rate=dropout_rate, l2_reg=l2_reg) # (128x128x16)

    # Output layer
    outputs = layers.Conv2D(1, kernel_size=(1, 1), activation="sigmoid")(c7)
    print(f"[Model_2D_SpatialDropout] Output shape: {outputs.shape}")

    model = models.Model(inputs, outputs)
    return model

# %%
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.layers import Input

def attention_gate(x, gating, inter_shape):
    """
    Creates an attention gate to focus on relevant features.
    
    Args:
        x (tf.Tensor): Input tensor from the encoder.
        gating (tf.Tensor): Tensor from the decoder (gating signal).
        inter_shape (int): Number of intermediate filters.
    
    Returns:
        tf.Tensor: Output tensor after applying attention.
    """
    # Theta path (downsampled)
    theta_x = layers.Conv2D(inter_shape, kernel_size=(1,1), strides=(2,2), padding='same')(x)  # Shape: (16,16,32)
    
    # Phi path (no downsampling)
    phi_g = layers.Conv2D(inter_shape, kernel_size=(1,1), padding='same')(gating)  # Shape: (32,32,32)
    phi_g = layers.AveragePooling2D(pool_size=(2,2), strides=(2,2), padding='same')(phi_g)  # Shape: (16,16,32)
    
    # Add theta_x and phi_g
    add_xg = layers.add([theta_x, phi_g])  # Shape: (16,16,32)
    act_xg = layers.Activation('relu')(add_xg)
    
    # Psi path
    psi = layers.Conv2D(1, kernel_size=(1,1), padding='same')(act_xg)  # Shape: (16,16,1)
    psi = layers.Activation('sigmoid')(psi)  # Shape: (16,16,1)
    
    # Upsample psi to match the encoder feature map size
    upsample_psi = layers.UpSampling2D(size=(2,2), interpolation='bilinear')(psi)  # Shape: (32,32,1)
    
    # Multiply attention coefficients with the original encoder feature map
    attn_coefficients = layers.multiply([x, upsample_psi])  # Shape: (32,32,64) * (32,32,1) = (32,32,64)
    
    return attn_coefficients


def residual_block_2d_attention(input_tensor, filters, dropout_rate=0.2, l2_reg=1e-5):
    """
    Create a residual block for the 2D segmentation model with Spatial Dropout and Attention.
    
    Args:
        input_tensor (tf.Tensor): Input tensor.
        filters (int): Number of filters for the convolutional layers.
        dropout_rate (float): Dropout rate for regularization.
        l2_reg (float): L2 regularization factor.
    
    Returns:
        tf.Tensor: Output tensor after applying the residual block.
    """
    reg = regularizers.l2(l2_reg)

    # First convolution
    x = layers.Conv2D(filters, kernel_size=(3, 3), padding="same", kernel_regularizer=reg)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Second convolution
    x = layers.Conv2D(filters, kernel_size=(3, 3), padding="same", kernel_regularizer=reg)(x)
    x = layers.BatchNormalization()(x)

    # Projection shortcut if input and output shapes differ
    if input_tensor.shape[-1] != filters:
        input_tensor = layers.Conv2D(filters, kernel_size=(1, 1), padding="same", kernel_regularizer=reg)(input_tensor)
        input_tensor = layers.BatchNormalization()(input_tensor)

    # Add skip connection
    x = layers.add([x, input_tensor])
    x = layers.ReLU()(x)

    # Add Spatial Dropout
    x = layers.SpatialDropout2D(dropout_rate)(x)
    return x

def build_residual_2d_unet_attention(input_shape=(128, 128, 1), dropout_rate=0.2, l2_reg=1e-5):
    """
    Build a residual-based 2D U-Net segmentation model with Attention Mechanism.
    
    Args:
        input_shape (tuple): Shape of the input data (height, width, channels).
        dropout_rate (float): Dropout rate for regularization.
        l2_reg (float): L2 regularization factor.
    
    Returns:
        tf.keras.Model: Compiled 2D U-Net model with Attention Mechanism.
    """
    inputs = Input(shape=input_shape)
    print(f"[Model_2D_Attention] Input shape: {inputs.shape}")

    # Encoder
    c1 = layers.Conv2D(16, kernel_size=(3, 3), padding="same", kernel_regularizer=regularizers.l2(l2_reg))(inputs)
    c1 = residual_block_2d_attention(c1, filters=16, dropout_rate=dropout_rate, l2_reg=l2_reg)
    p1 = layers.MaxPooling2D(pool_size=(2, 2))(c1)   # (64x64x16)

    c2 = residual_block_2d_attention(p1, filters=32, dropout_rate=dropout_rate, l2_reg=l2_reg)
    p2 = layers.MaxPooling2D(pool_size=(2, 2))(c2)   # (32x32x32)

    c3 = residual_block_2d_attention(p2, filters=64, dropout_rate=dropout_rate, l2_reg=l2_reg)
    p3 = layers.MaxPooling2D(pool_size=(2, 2))(c3)   # (16x16x64)

    # Bottleneck
    c4 = residual_block_2d_attention(p3, filters=128, dropout_rate=dropout_rate, l2_reg=l2_reg)
    print(f"[Model_2D_Attention] Bottleneck shape: {c4.shape}")

    # Decoder
    u3 = layers.Conv2DTranspose(64, kernel_size=(2, 2), strides=(2, 2), padding="same")(c4)
    # Apply attention gate
    attn3 = attention_gate(c3, u3, inter_shape=32)
    u3 = layers.multiply([u3, attn3])  # Apply attention coefficients
    c5 = residual_block_2d_attention(u3, filters=64, dropout_rate=dropout_rate, l2_reg=l2_reg) # (32x32x64)

    u2 = layers.Conv2DTranspose(32, kernel_size=(2, 2), strides=(2, 2), padding="same")(c5)
    attn2 = attention_gate(c2, u2, inter_shape=16)
    u2 = layers.multiply([u2, attn2])  # Apply attention coefficients
    c6 = residual_block_2d_attention(u2, filters=32, dropout_rate=dropout_rate, l2_reg=l2_reg) # (64x64x32)

    u1 = layers.Conv2DTranspose(16, kernel_size=(2, 2), strides=(2, 2), padding="same")(c6)
    attn1 = attention_gate(c1, u1, inter_shape=8)
    u1 = layers.multiply([u1, attn1])  # Apply attention coefficients
    c7 = residual_block_2d_attention(u1, filters=16, dropout_rate=dropout_rate, l2_reg=l2_reg) # (128x128x16)

    # Output layer
    outputs = layers.Conv2D(1, kernel_size=(1, 1), activation="sigmoid")(c7)
    print(f"[Model_2D_Attention] Output shape: {outputs.shape}")

    model = models.Model(inputs, outputs)
    return model

# %%
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.layers import Input

def squeeze_excite_block(input_tensor, ratio=16):
    """
    Create a Squeeze-and-Excitation (SE) block.
    
    Args:
        input_tensor (tf.Tensor): Input tensor.
        ratio (int): Reduction ratio for the SE block.
    
    Returns:
        tf.Tensor: Output tensor after applying SE block.
    """
    init = input_tensor
    channel_axis = -1
    filters = init.shape[channel_axis]
    
    se = layers.GlobalAveragePooling2D()(init)
    se = layers.Dense(filters // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
    se = layers.Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)
    se = layers.Reshape((1, 1, filters))(se)
    x = layers.multiply([init, se])
    return x

def residual_block_2d_se(input_tensor, filters, dropout_rate=0.2, l2_reg=1e-5, ratio=16):
    """
    Create a residual block for the 2D segmentation model with SE Blocks and Spatial Dropout.
    
    Args:
        input_tensor (tf.Tensor): Input tensor.
        filters (int): Number of filters for the convolutional layers.
        dropout_rate (float): Dropout rate for regularization.
        l2_reg (float): L2 regularization factor.
        ratio (int): Reduction ratio for the SE block.
    
    Returns:
        tf.Tensor: Output tensor after applying the residual block.
    """
    reg = regularizers.l2(l2_reg)

    # First convolution
    x = layers.Conv2D(filters, kernel_size=(3, 3), padding="same", kernel_regularizer=reg)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Second convolution
    x = layers.Conv2D(filters, kernel_size=(3, 3), padding="same", kernel_regularizer=reg)(x)
    x = layers.BatchNormalization()(x)

    # Squeeze-and-Excitation
    x = squeeze_excite_block(x, ratio=ratio)

    # Projection shortcut if input and output shapes differ
    if input_tensor.shape[-1] != filters:
        input_tensor = layers.Conv2D(filters, kernel_size=(1, 1), padding="same", kernel_regularizer=reg)(input_tensor)
        input_tensor = layers.BatchNormalization()(input_tensor)

    # Add skip connection
    x = layers.add([x, input_tensor])
    x = layers.ReLU()(x)

    # Add Spatial Dropout
    x = layers.SpatialDropout2D(dropout_rate)(x)
    return x


def build_residual_2d_unet_se(input_shape=(128, 128, 1), dropout_rate=0.2, l2_reg=1e-5, se_ratio=16):
    """
    Build a residual-based 2D U-Net segmentation model with Squeeze-and-Excitation (SE) Blocks.
    
    Args:
        input_shape (tuple): Shape of the input data (height, width, channels).
        dropout_rate (float): Dropout rate for regularization.
        l2_reg (float): L2 regularization factor.
        se_ratio (int): Reduction ratio for the SE blocks.
    
    Returns:
        tf.keras.Model: Compiled 2D U-Net model with SE Blocks.
    """
    inputs = Input(shape=input_shape)
    print(f"[Model_2D_SE] Input shape: {inputs.shape}")

    # Encoder
    c1 = layers.Conv2D(16, kernel_size=(3, 3), padding="same", kernel_regularizer=regularizers.l2(l2_reg))(inputs)
    c1 = residual_block_2d_se(c1, filters=16, dropout_rate=dropout_rate, l2_reg=l2_reg, ratio=se_ratio)
    p1 = layers.MaxPooling2D(pool_size=(2, 2))(c1)   # (64x64x16)

    c2 = residual_block_2d_se(p1, filters=32, dropout_rate=dropout_rate, l2_reg=l2_reg, ratio=se_ratio)
    p2 = layers.MaxPooling2D(pool_size=(2, 2))(c2)   # (32x32x32)

    c3 = residual_block_2d_se(p2, filters=64, dropout_rate=dropout_rate, l2_reg=l2_reg, ratio=se_ratio)
    p3 = layers.MaxPooling2D(pool_size=(2, 2))(c3)   # (16x16x64)

    # Bottleneck
    c4 = residual_block_2d_se(p3, filters=128, dropout_rate=dropout_rate, l2_reg=l2_reg, ratio=se_ratio)
    print(f"[Model_2D_SE] Bottleneck shape: {c4.shape}")

    # Decoder
    u3 = layers.Conv2DTranspose(64, kernel_size=(2, 2), strides=(2, 2), padding="same")(c4)
    u3 = layers.concatenate([u3, c3])
    c5 = residual_block_2d_se(u3, filters=64, dropout_rate=dropout_rate, l2_reg=l2_reg, ratio=se_ratio) # (32x32x64)

    u2 = layers.Conv2DTranspose(32, kernel_size=(2, 2), strides=(2, 2), padding="same")(c5)
    u2 = layers.concatenate([u2, c2])
    c6 = residual_block_2d_se(u2, filters=32, dropout_rate=dropout_rate, l2_reg=l2_reg, ratio=se_ratio) # (64x64x32)

    u1 = layers.Conv2DTranspose(16, kernel_size=(2, 2), strides=(2, 2), padding="same")(c6)
    u1 = layers.concatenate([u1, c1])
    c7 = residual_block_2d_se(u1, filters=16, dropout_rate=dropout_rate, l2_reg=l2_reg, ratio=se_ratio) # (128x128x16)

    # Output layer
    outputs = layers.Conv2D(1, kernel_size=(1, 1), activation="sigmoid")(c7)
    print(f"[Model_2D_SE] Output shape: {outputs.shape}")

    model = models.Model(inputs, outputs)
    return model

# %%
def count_cases(data_dir, dataset_type):
    """
    Count the number of cases in the dataset.

    Args:
        data_dir (Path): Path to the dataset directory.
        dataset_type (str): 'train' or 'test'.

    Returns:
        int: Number of cases.
    """
    num_cases = len(list((data_dir / dataset_type).glob("Case*.mhd")))
    #print(f"[Info] Number of {dataset_type} cases: {num_cases}")
    return num_cases

# %%
import datetime
from pathlib import Path

# Define paths and parameters
data_dir = Path("datasets")  # Update this path as needed
batch_size = 32
patch_size = (128, 128)
input_shape = (patch_size[0], patch_size[1], 1)
epochs = 50
patience = 5

# Define augmentation parameters
augmentations = {
    'zoom': True,
    'zoom_range': (0.9, 1.1),
    'shift': True,
    'shift_range': 10,
    'elastic': True,
    'elastic_alpha': 1000,
    'elastic_sigma': 50,
    'noise': True,
    'noise_mean': 0,
    'noise_std': 0.01,
    'rotation': True,
    'rotation_range': (-15, 15),
    'flip': True,
    'brightness_contrast': True,
    'brightness_range': (0.8, 1.2),
    'contrast_range': (0.8, 1.2),
    'affine': True,
    'affine_rotation_range': (-10, 10),
    'affine_translation_range': (-5, 5),
    'affine_shear_range': (-5, 5),
    'affine_zoom_range': (0.9, 1.1)
}

# %%
def dice_coefficient(y_true, y_pred, smooth=1e-5):
    # Cast y_pred to float32 to match y_true
    y_pred = K.cast(y_pred, 'float32')
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    """
    Computes the Dice Loss.

    Args:
        y_true (tf.Tensor): Ground truth masks.
        y_pred (tf.Tensor): Predicted masks.

    Returns:
        tf.Tensor: Dice loss.
    """
    return 1 - dice_coefficient(y_true, y_pred)

# %%
def train_model(model_builder, model_name, data_dir, batch_size, patch_size, input_shape, epochs, patience, augmentations, l2_reg=1e-5):
    """
    Trains and saves a model based on the provided model builder function.
    
    Args:
        model_builder (function): Function to build the model.
        model_name (str): Name identifier for the model.
        data_dir (Path): Path to the dataset directory.
        batch_size (int): Batch size for training.
        patch_size (tuple): Desired (height, width) of each patch.
        input_shape (tuple): Shape of the input data (height, width, channels).
        epochs (int): Number of training epochs.
        patience (int): Patience for EarlyStopping.
        augmentations (dict): Dictionary specifying augmentations to apply.
        l2_reg (float): L2 regularization factor.
    
    Returns:
        tf.keras.Model: Trained model.
    """
    # Initialize generators
    train_generator = dataset_generator_2d(
        data_dir=data_dir,
        batch_size=batch_size,
        patch_size=patch_size,
        dataset_type="train",
        augmentations=augmentations,
        prostatex_data=(prostatex_images, prostatex_masks)
    )
    val_generator = dataset_generator_2d(
        data_dir=data_dir,
        batch_size=batch_size,
        patch_size=patch_size,
        dataset_type="test",
        augmentations=None,
        prostatex_data=(prostatex_images, prostatex_masks)
    )
    
    # Calculate steps
    num_train_slices = calculate_steps_2d(data_dir, 'train', 8, patch_size)
    num_val_slices = calculate_steps_2d(data_dir, 'test', 8, patch_size)
    
    steps_per_epoch = num_train_slices // batch_size
    validation_steps = num_val_slices // batch_size
    
    print(f"[Train {model_name}] Total training slices: {num_train_slices}, Steps per epoch: {steps_per_epoch}")
    print(f"[Train {model_name}] Total validation slices: {num_val_slices}, Validation steps: {validation_steps}")
    
    # Build the model
    model = model_builder(input_shape=input_shape, dropout_rate=0.3, l2_reg=l2_reg)
    model.summary()
    
    # Compile the model
    model.compile(
        optimizer=optimizers.Adam(learning_rate=1e-4),
        loss=dice_loss,
        metrics=[dice_coefficient, 'accuracy', MeanIoU(num_classes=2)]
    )
    print(f"[Train {model_name}] Model compiled successfully.")
    
    # Define callbacks
    checkpoint = ModelCheckpoint(
        f"best_model_{model_name}.keras",
        monitor='val_dice_coefficient',
        mode='max',
        save_best_only=True,
        verbose=1
    )
    early_stop = EarlyStopping(
        monitor='val_dice_coefficient',
        patience=patience,
        mode='max',
        verbose=1,
        restore_best_weights=True
    )
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        verbose=1,
        mode='min',
        min_lr=1e-6
    )
    tensorboard_callback = TensorBoard(
        log_dir=f"logs/{model_name}/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"),
        histogram_freq=1
    )
    
    callbacks = [checkpoint, early_stop, reduce_lr, tensorboard_callback]
    
    # Train the model
    print(f"[Train {model_name}] Starting training...")
    history = model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=epochs,
        validation_data=val_generator,
        validation_steps=validation_steps,
        callbacks=callbacks
    )
    print(f"[Train {model_name}] Training completed.")
    
    # Save the final model
    model.save(f"final_model_{model_name}.keras")
    print(f"[Train {model_name}] Final model saved as 'final_model_{model_name}.keras'.")
    
    return model

# %%
train = input("Train the models? (y/n): ")

#train = 'y'

if train.lower() != 'y':
    print("Exiting...")

else:
    
    # Train Model 1: Residual U-Net with Spatial Dropout
    model1 = train_model(
        model_builder=build_residual_2d_unet_spatial_dropout,
        model_name="residual_spatial_dropout",
        data_dir=data_dir,
        batch_size=batch_size,
        patch_size=patch_size,
        input_shape=input_shape,
        epochs=epochs,
        patience=patience,
        augmentations=augmentations,
        l2_reg=1e-5
    )
    
    # Train Model 2: Residual U-Net with Attention Mechanism
    model2 = train_model(
        model_builder=build_residual_2d_unet_attention,
        model_name="residual_attention",
        data_dir=data_dir,
        batch_size=batch_size,
        patch_size=patch_size,
        input_shape=input_shape,
        epochs=epochs,
        patience=patience,
        augmentations=augmentations,
        l2_reg=1e-5
    )
    
    # Train Model 3: Residual U-Net with SE Blocks
    model3 = train_model(
        model_builder=build_residual_2d_unet_se,
        model_name="residual_se",
        data_dir=data_dir,
        batch_size=batch_size,
        patch_size=patch_size,
        input_shape=input_shape,
        epochs=epochs,
        patience=patience,
        augmentations=augmentations,
        l2_reg=1e-5
    )
# Out:
# [Train residual_spatial_dropout] Total training slices: 4265, Steps per epoch: 133
# [Train residual_spatial_dropout] Total validation slices: 2497, Validation steps: 78
# [Model_2D_SpatialDropout] Input shape: (None, 128, 128, 1)
# [Model_2D_SpatialDropout] Bottleneck shape: (None, 16, 16, 128)
# [Model_2D_SpatialDropout] Output shape: (None, 128, 128, 1)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cast (Cast)               │ (None, 128, 128, 1)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 128, 128, 16)   │            160 │ cast[0][0]             │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 128, 128, 16)   │          2,320 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 128, 128, 16)   │             64 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 128, 128, 16)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 16)   │          2,320 │ re_lu[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 128, 128, 16)   │             64 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 128, 128, 16)   │              0 │ batch_normalization_1… │
# │                           │                        │                │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 128, 128, 16)   │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d         │ (None, 128, 128, 16)   │              0 │ re_lu_1[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 64, 64, 16)     │              0 │ spatial_dropout2d[0][… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 64, 64, 32)     │          4,640 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 64, 64, 32)     │            128 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 64, 64, 32)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 32)     │          9,248 │ re_lu_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 32)     │            544 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 64, 64, 32)     │            128 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 32)     │            128 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 64, 64, 32)     │              0 │ batch_normalization_3… │
# │                           │                        │                │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 64, 64, 32)     │              0 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_1       │ (None, 64, 64, 32)     │              0 │ re_lu_3[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 32, 32, 32)     │              0 │ spatial_dropout2d_1[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 32, 64)     │         18,496 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 32, 32, 64)     │            256 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 32, 32, 64)     │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 64)     │         36,928 │ re_lu_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 32, 32, 64)     │          2,112 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 32, 64)     │            256 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 64)     │            256 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 32, 32, 64)     │              0 │ batch_normalization_6… │
# │                           │                        │                │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_5 (ReLU)            │ (None, 32, 32, 64)     │              0 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_2       │ (None, 32, 32, 64)     │              0 │ re_lu_5[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 16, 16, 64)     │              0 │ spatial_dropout2d_2[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 16, 16, 128)    │         73,856 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 16, 16, 128)    │            512 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_6 (ReLU)            │ (None, 16, 16, 128)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 16, 16, 128)    │        147,584 │ re_lu_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 16, 16, 128)    │          8,320 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 16, 16, 128)    │            512 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 16, 16, 128)    │            512 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 16, 16, 128)    │              0 │ batch_normalization_9… │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_7 (ReLU)            │ (None, 16, 16, 128)    │              0 │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_3       │ (None, 16, 16, 128)    │              0 │ re_lu_7[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 32, 64)     │         32,832 │ spatial_dropout2d_3[0… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 128)    │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ spatial_dropout2d_2[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 32, 32, 64)     │         73,792 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 32, 32, 64)     │            256 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_8 (ReLU)            │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ re_lu_8[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 32, 32, 64)     │          8,256 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 32, 32, 64)     │            256 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 32, 32, 64)     │            256 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_9 (ReLU)            │ (None, 32, 32, 64)     │              0 │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_4       │ (None, 32, 32, 64)     │              0 │ re_lu_9[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 64, 64, 32)     │          8,224 │ spatial_dropout2d_4[0… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 64)     │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 64, 64, 32)     │         18,464 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 64, 64, 32)     │            128 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_10 (ReLU)           │ (None, 64, 64, 32)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 64, 64, 32)     │          9,248 │ re_lu_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 64, 64, 32)     │          2,080 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 64, 64, 32)     │            128 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 64, 64, 32)     │            128 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 64, 64, 32)     │              0 │ batch_normalization_1… │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_11 (ReLU)           │ (None, 64, 64, 32)     │              0 │ add_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_5       │ (None, 64, 64, 32)     │              0 │ re_lu_11[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 128, 128, 16)   │          2,064 │ spatial_dropout2d_5[0… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 128, 128, 32)   │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 128, 128, 16)   │          4,624 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 128, 128, 16)   │             64 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_12 (ReLU)           │ (None, 128, 128, 16)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 128, 128, 16)   │          2,320 │ re_lu_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 128, 128, 16)   │            528 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 128, 128, 16)   │             64 │ conv2d_19[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 128, 128, 16)   │             64 │ conv2d_20[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 128, 128, 16)   │              0 │ batch_normalization_1… │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_13 (ReLU)           │ (None, 128, 128, 16)   │              0 │ add_6[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_6       │ (None, 128, 128, 16)   │              0 │ re_lu_13[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 128, 128, 1)    │             17 │ spatial_dropout2d_6[0… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 510,065 (1.95 MB)
#  Trainable params: 507,985 (1.94 MB)
#  Non-trainable params: 2,080 (8.12 KB)
# [Train residual_spatial_dropout] Model compiled successfully.
# [Train residual_spatial_dropout] Starting training...
# Epoch 1/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7984 - dice_coefficient: 0.0768 - loss: 0.9328 - mean_io_u: 0.4552
# Epoch 1: val_dice_coefficient improved from -inf to 0.07121, saving model to best_model_residual_spatial_dropout.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - accuracy: 0.7983 - dice_coefficient: 0.0768 - loss: 0.9328 - mean_io_u: 0.4550 - val_accuracy: 0.8080 - val_dice_coefficient: 0.0712 - val_loss: 0.9382 - val_mean_io_u: 0.4614 - learning_rate: 1.0000e-04
# Epoch 2/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7514 - dice_coefficient: 0.0931 - loss: 0.9164 - mean_io_u: 0.4610
# Epoch 2: val_dice_coefficient did not improve from 0.07121
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.7512 - dice_coefficient: 0.0932 - loss: 0.9163 - mean_io_u: 0.4608 - val_accuracy: 0.9540 - val_dice_coefficient: 0.0500 - val_loss: 0.9594 - val_mean_io_u: 0.4532 - learning_rate: 1.0000e-04
# Epoch 3/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7108 - dice_coefficient: 0.1373 - loss: 0.8722 - mean_io_u: 0.4614
# Epoch 3: val_dice_coefficient improved from 0.07121 to 0.17100, saving model to best_model_residual_spatial_dropout.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.7110 - dice_coefficient: 0.1375 - loss: 0.8721 - mean_io_u: 0.4611 - val_accuracy: 0.6690 - val_dice_coefficient: 0.1710 - val_loss: 0.8378 - val_mean_io_u: 0.4537 - learning_rate: 1.0000e-04
# Epoch 4/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8041 - dice_coefficient: 0.1645 - loss: 0.8448 - mean_io_u: 0.4839
# Epoch 4: val_dice_coefficient did not improve from 0.17100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.8042 - dice_coefficient: 0.1647 - loss: 0.8446 - mean_io_u: 0.4838 - val_accuracy: 0.8147 - val_dice_coefficient: 0.1578 - val_loss: 0.8515 - val_mean_io_u: 0.5029 - learning_rate: 1.0000e-04
# Epoch 5/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8643 - dice_coefficient: 0.2367 - loss: 0.7727 - mean_io_u: 0.4980
# Epoch 5: val_dice_coefficient improved from 0.17100 to 0.25877, saving model to best_model_residual_spatial_dropout.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.8643 - dice_coefficient: 0.2367 - loss: 0.7726 - mean_io_u: 0.4978 - val_accuracy: 0.8518 - val_dice_coefficient: 0.2588 - val_loss: 0.7508 - val_mean_io_u: 0.5873 - learning_rate: 1.0000e-04
# Epoch 6/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9022 - dice_coefficient: 0.2942 - loss: 0.7150 - mean_io_u: 0.5307
# Epoch 6: val_dice_coefficient improved from 0.25877 to 0.32705, saving model to best_model_residual_spatial_dropout.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9022 - dice_coefficient: 0.2941 - loss: 0.7150 - mean_io_u: 0.5304 - val_accuracy: 0.8726 - val_dice_coefficient: 0.3270 - val_loss: 0.6825 - val_mean_io_u: 0.6184 - learning_rate: 1.0000e-04
# Epoch 7/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9078 - dice_coefficient: 0.3282 - loss: 0.6823 - mean_io_u: 0.5296
# Epoch 7: val_dice_coefficient did not improve from 0.32705
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.9078 - dice_coefficient: 0.3283 - loss: 0.6822 - mean_io_u: 0.5293 - val_accuracy: 0.9134 - val_dice_coefficient: 0.2857 - val_loss: 0.7236 - val_mean_io_u: 0.6034 - learning_rate: 1.0000e-04
# Epoch 8/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9259 - dice_coefficient: 0.3003 - loss: 0.7082 - mean_io_u: 0.5486
# Epoch 8: val_dice_coefficient did not improve from 0.32705
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.9260 - dice_coefficient: 0.3005 - loss: 0.7080 - mean_io_u: 0.5484 - val_accuracy: 0.9217 - val_dice_coefficient: 0.3177 - val_loss: 0.6926 - val_mean_io_u: 0.5863 - learning_rate: 1.0000e-04
# Epoch 9/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9363 - dice_coefficient: 0.3479 - loss: 0.6619 - mean_io_u: 0.5501
# Epoch 9: val_dice_coefficient improved from 0.32705 to 0.38755, saving model to best_model_residual_spatial_dropout.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9362 - dice_coefficient: 0.3480 - loss: 0.6617 - mean_io_u: 0.5498 - val_accuracy: 0.8999 - val_dice_coefficient: 0.3876 - val_loss: 0.6214 - val_mean_io_u: 0.6437 - learning_rate: 1.0000e-04
# Epoch 10/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9367 - dice_coefficient: 0.3842 - loss: 0.6251 - mean_io_u: 0.5508
# Epoch 10: val_dice_coefficient improved from 0.38755 to 0.39736, saving model to best_model_residual_spatial_dropout.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.9367 - dice_coefficient: 0.3842 - loss: 0.6251 - mean_io_u: 0.5505 - val_accuracy: 0.9285 - val_dice_coefficient: 0.3974 - val_loss: 0.6120 - val_mean_io_u: 0.6423 - learning_rate: 1.0000e-04
# Epoch 11/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9437 - dice_coefficient: 0.3933 - loss: 0.6154 - mean_io_u: 0.5585
# Epoch 11: val_dice_coefficient did not improve from 0.39736
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9436 - dice_coefficient: 0.3933 - loss: 0.6154 - mean_io_u: 0.5582 - val_accuracy: 0.9540 - val_dice_coefficient: 0.3419 - val_loss: 0.6693 - val_mean_io_u: 0.5664 - learning_rate: 1.0000e-04
# Epoch 12/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9503 - dice_coefficient: 0.4192 - loss: 0.5911 - mean_io_u: 0.5760
# Epoch 12: val_dice_coefficient improved from 0.39736 to 0.48495, saving model to best_model_residual_spatial_dropout.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - accuracy: 0.9503 - dice_coefficient: 0.4192 - loss: 0.5911 - mean_io_u: 0.5758 - val_accuracy: 0.9523 - val_dice_coefficient: 0.4850 - val_loss: 0.5246 - val_mean_io_u: 0.6835 - learning_rate: 1.0000e-04
# Epoch 13/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9458 - dice_coefficient: 0.4444 - loss: 0.5653 - mean_io_u: 0.5600
# Epoch 13: val_dice_coefficient did not improve from 0.48495
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9458 - dice_coefficient: 0.4443 - loss: 0.5654 - mean_io_u: 0.5599 - val_accuracy: 0.9543 - val_dice_coefficient: 0.4172 - val_loss: 0.5932 - val_mean_io_u: 0.6552 - learning_rate: 1.0000e-04
# Epoch 14/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9497 - dice_coefficient: 0.4419 - loss: 0.5676 - mean_io_u: 0.5607
# Epoch 14: val_dice_coefficient did not improve from 0.48495
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9497 - dice_coefficient: 0.4420 - loss: 0.5675 - mean_io_u: 0.5606 - val_accuracy: 0.9620 - val_dice_coefficient: 0.3768 - val_loss: 0.6326 - val_mean_io_u: 0.5936 - learning_rate: 1.0000e-04
# Epoch 15/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9482 - dice_coefficient: 0.4812 - loss: 0.5282 - mean_io_u: 0.5673
# Epoch 15: val_dice_coefficient did not improve from 0.48495
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9483 - dice_coefficient: 0.4810 - loss: 0.5284 - mean_io_u: 0.5672 - val_accuracy: 0.9508 - val_dice_coefficient: 0.4161 - val_loss: 0.5939 - val_mean_io_u: 0.6365 - learning_rate: 1.0000e-04
# Epoch 16/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9579 - dice_coefficient: 0.4609 - loss: 0.5445 - mean_io_u: 0.5846
# Epoch 16: val_dice_coefficient improved from 0.48495 to 0.55217, saving model to best_model_residual_spatial_dropout.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9579 - dice_coefficient: 0.4610 - loss: 0.5445 - mean_io_u: 0.5843 - val_accuracy: 0.9588 - val_dice_coefficient: 0.5522 - val_loss: 0.4566 - val_mean_io_u: 0.6921 - learning_rate: 1.0000e-04
# Epoch 17/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9590 - dice_coefficient: 0.4906 - loss: 0.5195 - mean_io_u: 0.5975
# Epoch 17: val_dice_coefficient did not improve from 0.55217
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.9590 - dice_coefficient: 0.4905 - loss: 0.5196 - mean_io_u: 0.5973 - val_accuracy: 0.9708 - val_dice_coefficient: 0.3670 - val_loss: 0.6424 - val_mean_io_u: 0.6157 - learning_rate: 1.0000e-04
# Epoch 18/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9479 - dice_coefficient: 0.4619 - loss: 0.5477 - mean_io_u: 0.5572
# Epoch 18: val_dice_coefficient did not improve from 0.55217
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9479 - dice_coefficient: 0.4620 - loss: 0.5476 - mean_io_u: 0.5572 - val_accuracy: 0.9558 - val_dice_coefficient: 0.4455 - val_loss: 0.5644 - val_mean_io_u: 0.6453 - learning_rate: 1.0000e-04
# Epoch 19/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9530 - dice_coefficient: 0.5053 - loss: 0.5040 - mean_io_u: 0.5712
# Epoch 19: val_dice_coefficient did not improve from 0.55217
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9531 - dice_coefficient: 0.5053 - loss: 0.5041 - mean_io_u: 0.5711 - val_accuracy: 0.9568 - val_dice_coefficient: 0.5436 - val_loss: 0.4656 - val_mean_io_u: 0.7052 - learning_rate: 1.0000e-04
# Epoch 20/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9618 - dice_coefficient: 0.5323 - loss: 0.4771 - mean_io_u: 0.6001
# Epoch 20: val_dice_coefficient did not improve from 0.55217
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.9618 - dice_coefficient: 0.5320 - loss: 0.4773 - mean_io_u: 0.5998 - val_accuracy: 0.9664 - val_dice_coefficient: 0.3780 - val_loss: 0.6313 - val_mean_io_u: 0.6469 - learning_rate: 1.0000e-04
# Epoch 21/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9618 - dice_coefficient: 0.5459 - loss: 0.4642 - mean_io_u: 0.5967
# Epoch 21: val_dice_coefficient did not improve from 0.55217
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9618 - dice_coefficient: 0.5458 - loss: 0.4643 - mean_io_u: 0.5965 - val_accuracy: 0.9624 - val_dice_coefficient: 0.4368 - val_loss: 0.5734 - val_mean_io_u: 0.6346 - learning_rate: 1.0000e-04
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 16.
# [Train residual_spatial_dropout] Training completed.
# [Train residual_spatial_dropout] Final model saved as 'final_model_residual_spatial_dropout.keras'.
# [Train residual_attention] Total training slices: 4265, Steps per epoch: 133
# [Train residual_attention] Total validation slices: 2497, Validation steps: 78
# [Model_2D_Attention] Input shape: (None, 128, 128, 1)
# [Model_2D_Attention] Bottleneck shape: (None, 16, 16, 128)
# [Model_2D_Attention] Output shape: (None, 128, 128, 1)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 128, 128, 1)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cast_1 (Cast)             │ (None, 128, 128, 1)    │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 128, 128, 16)   │            160 │ cast_1[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 128, 128, 16)   │          2,320 │ conv2d_22[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 128, 128, 16)   │             64 │ conv2d_23[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_14 (ReLU)           │ (None, 128, 128, 16)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 128, 128, 16)   │          2,320 │ re_lu_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 128, 128, 16)   │             64 │ conv2d_24[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 128, 128, 16)   │              0 │ batch_normalization_2… │
# │                           │                        │                │ conv2d_22[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_15 (ReLU)           │ (None, 128, 128, 16)   │              0 │ add_7[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_7       │ (None, 128, 128, 16)   │              0 │ re_lu_15[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 64, 64, 16)     │              0 │ spatial_dropout2d_7[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 64, 64, 32)     │          4,640 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 64, 64, 32)     │            128 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_16 (ReLU)           │ (None, 64, 64, 32)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 64, 64, 32)     │          9,248 │ re_lu_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 64, 64, 32)     │            544 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 64, 64, 32)     │            128 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 64, 64, 32)     │            128 │ conv2d_27[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 64, 64, 32)     │              0 │ batch_normalization_2… │
# │                           │                        │                │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_17 (ReLU)           │ (None, 64, 64, 32)     │              0 │ add_8[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_8       │ (None, 64, 64, 32)     │              0 │ re_lu_17[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 32, 32, 32)     │              0 │ spatial_dropout2d_8[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 32, 32, 64)     │         18,496 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_25    │ (None, 32, 32, 64)     │            256 │ conv2d_28[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_18 (ReLU)           │ (None, 32, 32, 64)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ re_lu_18[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_30 (Conv2D)        │ (None, 32, 32, 64)     │          2,112 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_26    │ (None, 32, 32, 64)     │            256 │ conv2d_29[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_27    │ (None, 32, 32, 64)     │            256 │ conv2d_30[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 32, 32, 64)     │              0 │ batch_normalization_2… │
# │                           │                        │                │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_19 (ReLU)           │ (None, 32, 32, 64)     │              0 │ add_9[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_9       │ (None, 32, 32, 64)     │              0 │ re_lu_19[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_5           │ (None, 16, 16, 64)     │              0 │ spatial_dropout2d_9[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_31 (Conv2D)        │ (None, 16, 16, 128)    │         73,856 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_28    │ (None, 16, 16, 128)    │            512 │ conv2d_31[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_20 (ReLU)           │ (None, 16, 16, 128)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_32 (Conv2D)        │ (None, 16, 16, 128)    │        147,584 │ re_lu_20[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_33 (Conv2D)        │ (None, 16, 16, 128)    │          8,320 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_29    │ (None, 16, 16, 128)    │            512 │ conv2d_32[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_30    │ (None, 16, 16, 128)    │            512 │ conv2d_33[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 16, 16, 128)    │              0 │ batch_normalization_2… │
# │                           │                        │                │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_21 (ReLU)           │ (None, 16, 16, 128)    │              0 │ add_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_10      │ (None, 16, 16, 128)    │              0 │ re_lu_21[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 32, 32, 64)     │         32,832 │ spatial_dropout2d_10[… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_35 (Conv2D)        │ (None, 32, 32, 32)     │          2,080 │ conv2d_transpose_3[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_34 (Conv2D)        │ (None, 16, 16, 32)     │          2,080 │ spatial_dropout2d_9[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d         │ (None, 16, 16, 32)     │              0 │ conv2d_35[0][0]        │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 16, 16, 32)     │              0 │ conv2d_34[0][0],       │
# │                           │                        │                │ average_pooling2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 16, 16, 32)     │              0 │ add_11[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_36 (Conv2D)        │ (None, 16, 16, 1)      │             33 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 16, 16, 1)      │              0 │ conv2d_36[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 32, 32, 1)      │              0 │ activation_1[0][0]     │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 32, 32, 64)     │              0 │ spatial_dropout2d_9[0… │
# │                           │                        │                │ up_sampling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 32, 32, 64)     │              0 │ conv2d_transpose_3[0]… │
# │                           │                        │                │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_37 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ multiply_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_31    │ (None, 32, 32, 64)     │            256 │ conv2d_37[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_22 (ReLU)           │ (None, 32, 32, 64)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ re_lu_22[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_32    │ (None, 32, 32, 64)     │            256 │ conv2d_38[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 32, 32, 64)     │              0 │ batch_normalization_3… │
# │                           │                        │                │ multiply_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_23 (ReLU)           │ (None, 32, 32, 64)     │              0 │ add_12[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_11      │ (None, 32, 32, 64)     │              0 │ re_lu_23[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_4        │ (None, 64, 64, 32)     │          8,224 │ spatial_dropout2d_11[… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_40 (Conv2D)        │ (None, 64, 64, 16)     │            528 │ conv2d_transpose_4[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 32, 32, 16)     │            528 │ spatial_dropout2d_8[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_1       │ (None, 32, 32, 16)     │              0 │ conv2d_40[0][0]        │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 32, 32, 16)     │              0 │ conv2d_39[0][0],       │
# ...
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 128, 128, 32)   │              0 │ conv2d_transpose_8[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_14[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_68 (Conv2D)        │ (None, 128, 128, 16)   │          4,624 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_54    │ (None, 128, 128, 16)   │             64 │ conv2d_68[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_40 (ReLU)           │ (None, 128, 128, 16)   │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_69 (Conv2D)        │ (None, 128, 128, 16)   │          2,320 │ re_lu_40[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_55    │ (None, 128, 128, 16)   │             64 │ conv2d_69[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 16)             │              0 │ batch_normalization_5… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_12 (Dense)          │ (None, 1)              │             16 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_13 (Dense)          │ (None, 16)             │             16 │ dense_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_6 (Reshape)       │ (None, 1, 1, 16)       │              0 │ dense_13[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_70 (Conv2D)        │ (None, 128, 128, 16)   │            528 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_12 (Multiply)    │ (None, 128, 128, 16)   │              0 │ batch_normalization_5… │
# │                           │                        │                │ reshape_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_56    │ (None, 128, 128, 16)   │             64 │ conv2d_70[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_23 (Add)              │ (None, 128, 128, 16)   │              0 │ multiply_12[0][0],     │
# │                           │                        │                │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_41 (ReLU)           │ (None, 128, 128, 16)   │              0 │ add_23[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_20      │ (None, 128, 128, 16)   │              0 │ re_lu_41[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_71 (Conv2D)        │ (None, 128, 128, 1)    │             17 │ spatial_dropout2d_20[… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 513,457 (1.96 MB)
#  Trainable params: 511,377 (1.95 MB)
#  Non-trainable params: 2,080 (8.12 KB)
# [Train residual_se] Model compiled successfully.
# [Train residual_se] Starting training...
# Epoch 1/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4000 - dice_coefficient: 0.0772 - loss: 0.9323 - mean_io_u_2: 0.4561
# Epoch 1: val_dice_coefficient improved from -inf to 0.06320, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 217s 1s/step - accuracy: 0.4001 - dice_coefficient: 0.0772 - loss: 0.9323 - mean_io_u_2: 0.4559 - val_accuracy: 0.5369 - val_dice_coefficient: 0.0632 - val_loss: 0.9460 - val_mean_io_u_2: 0.4614 - learning_rate: 1.0000e-04
# Epoch 2/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4226 - dice_coefficient: 0.0864 - loss: 0.9229 - mean_io_u_2: 0.4583
# Epoch 2: val_dice_coefficient improved from 0.06320 to 0.11539, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.4228 - dice_coefficient: 0.0864 - loss: 0.9229 - mean_io_u_2: 0.4581 - val_accuracy: 0.5639 - val_dice_coefficient: 0.1154 - val_loss: 0.8934 - val_mean_io_u_2: 0.4528 - learning_rate: 1.0000e-04
# Epoch 3/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5781 - dice_coefficient: 0.0985 - loss: 0.9106 - mean_io_u_2: 0.4779
# Epoch 3: val_dice_coefficient improved from 0.11539 to 0.14362, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.5782 - dice_coefficient: 0.0986 - loss: 0.9105 - mean_io_u_2: 0.4776 - val_accuracy: 0.6692 - val_dice_coefficient: 0.1436 - val_loss: 0.8652 - val_mean_io_u_2: 0.4912 - learning_rate: 1.0000e-04
# Epoch 4/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6475 - dice_coefficient: 0.1159 - loss: 0.8930 - mean_io_u_2: 0.4919
# Epoch 4: val_dice_coefficient did not improve from 0.14362
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.6477 - dice_coefficient: 0.1161 - loss: 0.8929 - mean_io_u_2: 0.4917 - val_accuracy: 0.7983 - val_dice_coefficient: 0.1206 - val_loss: 0.8883 - val_mean_io_u_2: 0.5317 - learning_rate: 1.0000e-04
# Epoch 5/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7100 - dice_coefficient: 0.1418 - loss: 0.8670 - mean_io_u_2: 0.5009
# Epoch 5: val_dice_coefficient improved from 0.14362 to 0.17414, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.7101 - dice_coefficient: 0.1419 - loss: 0.8670 - mean_io_u_2: 0.5006 - val_accuracy: 0.8140 - val_dice_coefficient: 0.1741 - val_loss: 0.8348 - val_mean_io_u_2: 0.4877 - learning_rate: 1.0000e-04
# Epoch 6/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7429 - dice_coefficient: 0.1593 - loss: 0.8515 - mean_io_u_2: 0.5078
# Epoch 6: val_dice_coefficient did not improve from 0.17414
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.7429 - dice_coefficient: 0.1593 - loss: 0.8514 - mean_io_u_2: 0.5075 - val_accuracy: 0.6773 - val_dice_coefficient: 0.1722 - val_loss: 0.8367 - val_mean_io_u_2: 0.5262 - learning_rate: 1.0000e-04
# Epoch 7/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7736 - dice_coefficient: 0.1766 - loss: 0.8321 - mean_io_u_2: 0.5208
# Epoch 7: val_dice_coefficient did not improve from 0.17414
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.7736 - dice_coefficient: 0.1766 - loss: 0.8320 - mean_io_u_2: 0.5205 - val_accuracy: 0.7919 - val_dice_coefficient: 0.1577 - val_loss: 0.8512 - val_mean_io_u_2: 0.5472 - learning_rate: 1.0000e-04
# Epoch 8/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7984 - dice_coefficient: 0.1957 - loss: 0.8128 - mean_io_u_2: 0.5182
# Epoch 8: val_dice_coefficient improved from 0.17414 to 0.21373, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.7984 - dice_coefficient: 0.1957 - loss: 0.8128 - mean_io_u_2: 0.5180 - val_accuracy: 0.8820 - val_dice_coefficient: 0.2137 - val_loss: 0.7952 - val_mean_io_u_2: 0.5672 - learning_rate: 1.0000e-04
# Epoch 9/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8197 - dice_coefficient: 0.1895 - loss: 0.8194 - mean_io_u_2: 0.5349
# Epoch 9: val_dice_coefficient improved from 0.21373 to 0.24480, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.8198 - dice_coefficient: 0.1898 - loss: 0.8192 - mean_io_u_2: 0.5346 - val_accuracy: 0.8243 - val_dice_coefficient: 0.2448 - val_loss: 0.7639 - val_mean_io_u_2: 0.6232 - learning_rate: 1.0000e-04
# Epoch 10/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8413 - dice_coefficient: 0.2370 - loss: 0.7717 - mean_io_u_2: 0.5301
# Epoch 10: val_dice_coefficient did not improve from 0.24480
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.8414 - dice_coefficient: 0.2370 - loss: 0.7718 - mean_io_u_2: 0.5299 - val_accuracy: 0.8834 - val_dice_coefficient: 0.2233 - val_loss: 0.7855 - val_mean_io_u_2: 0.6137 - learning_rate: 1.0000e-04
# Epoch 11/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8695 - dice_coefficient: 0.2471 - loss: 0.7628 - mean_io_u_2: 0.5513
# Epoch 11: val_dice_coefficient improved from 0.24480 to 0.24861, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.8696 - dice_coefficient: 0.2471 - loss: 0.7628 - mean_io_u_2: 0.5511 - val_accuracy: 0.9134 - val_dice_coefficient: 0.2486 - val_loss: 0.7606 - val_mean_io_u_2: 0.6031 - learning_rate: 1.0000e-04
# Epoch 12/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8827 - dice_coefficient: 0.2700 - loss: 0.7397 - mean_io_u_2: 0.5563
# Epoch 12: val_dice_coefficient improved from 0.24861 to 0.29387, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.8827 - dice_coefficient: 0.2700 - loss: 0.7397 - mean_io_u_2: 0.5560 - val_accuracy: 0.9141 - val_dice_coefficient: 0.2939 - val_loss: 0.7150 - val_mean_io_u_2: 0.6188 - learning_rate: 1.0000e-04
# Epoch 13/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8865 - dice_coefficient: 0.2725 - loss: 0.7368 - mean_io_u_2: 0.5542
# Epoch 13: val_dice_coefficient improved from 0.29387 to 0.30950, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.8865 - dice_coefficient: 0.2724 - loss: 0.7369 - mean_io_u_2: 0.5540 - val_accuracy: 0.9135 - val_dice_coefficient: 0.3095 - val_loss: 0.6994 - val_mean_io_u_2: 0.6355 - learning_rate: 1.0000e-04
# Epoch 14/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8987 - dice_coefficient: 0.2982 - loss: 0.7102 - mean_io_u_2: 0.5695
# Epoch 14: val_dice_coefficient did not improve from 0.30950
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.8987 - dice_coefficient: 0.2981 - loss: 0.7103 - mean_io_u_2: 0.5693 - val_accuracy: 0.9531 - val_dice_coefficient: 0.2278 - val_loss: 0.7809 - val_mean_io_u_2: 0.5672 - learning_rate: 1.0000e-04
# Epoch 15/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9085 - dice_coefficient: 0.2993 - loss: 0.7094 - mean_io_u_2: 0.5746
# Epoch 15: val_dice_coefficient improved from 0.30950 to 0.32831, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9086 - dice_coefficient: 0.2994 - loss: 0.7094 - mean_io_u_2: 0.5743 - val_accuracy: 0.9229 - val_dice_coefficient: 0.3283 - val_loss: 0.6804 - val_mean_io_u_2: 0.6190 - learning_rate: 1.0000e-04
# Epoch 16/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9114 - dice_coefficient: 0.2971 - loss: 0.7084 - mean_io_u_2: 0.5837
# Epoch 16: val_dice_coefficient improved from 0.32831 to 0.39076, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.9114 - dice_coefficient: 0.2971 - loss: 0.7083 - mean_io_u_2: 0.5834 - val_accuracy: 0.9294 - val_dice_coefficient: 0.3908 - val_loss: 0.6173 - val_mean_io_u_2: 0.6395 - learning_rate: 1.0000e-04
# Epoch 17/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9161 - dice_coefficient: 0.3150 - loss: 0.6945 - mean_io_u_2: 0.5843
# Epoch 17: val_dice_coefficient did not improve from 0.39076
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9161 - dice_coefficient: 0.3151 - loss: 0.6944 - mean_io_u_2: 0.5840 - val_accuracy: 0.9617 - val_dice_coefficient: 0.2743 - val_loss: 0.7344 - val_mean_io_u_2: 0.6371 - learning_rate: 1.0000e-04
# Epoch 18/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9194 - dice_coefficient: 0.3057 - loss: 0.7033 - mean_io_u_2: 0.5892
# Epoch 18: val_dice_coefficient did not improve from 0.39076
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9194 - dice_coefficient: 0.3058 - loss: 0.7031 - mean_io_u_2: 0.5889 - val_accuracy: 0.9458 - val_dice_coefficient: 0.3020 - val_loss: 0.7073 - val_mean_io_u_2: 0.6000 - learning_rate: 1.0000e-04
# Epoch 19/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9304 - dice_coefficient: 0.3309 - loss: 0.6779 - mean_io_u_2: 0.6038
# Epoch 19: val_dice_coefficient improved from 0.39076 to 0.39513, saving model to best_model_residual_se.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.9304 - dice_coefficient: 0.3310 - loss: 0.6778 - mean_io_u_2: 0.6035 - val_accuracy: 0.9264 - val_dice_coefficient: 0.3951 - val_loss: 0.6130 - val_mean_io_u_2: 0.6499 - learning_rate: 1.0000e-04
# Epoch 20/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9330 - dice_coefficient: 0.3534 - loss: 0.6553 - mean_io_u_2: 0.6044
# Epoch 20: val_dice_coefficient did not improve from 0.39513
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9330 - dice_coefficient: 0.3534 - loss: 0.6553 - mean_io_u_2: 0.6041 - val_accuracy: 0.9441 - val_dice_coefficient: 0.3233 - val_loss: 0.6854 - val_mean_io_u_2: 0.6454 - learning_rate: 1.0000e-04
# Epoch 21/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9374 - dice_coefficient: 0.3845 - loss: 0.6251 - mean_io_u_2: 0.6253
# Epoch 21: val_dice_coefficient did not improve from 0.39513
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9374 - dice_coefficient: 0.3845 - loss: 0.6251 - mean_io_u_2: 0.6249 - val_accuracy: 0.9590 - val_dice_coefficient: 0.3297 - val_loss: 0.6804 - val_mean_io_u_2: 0.6034 - learning_rate: 1.0000e-04
# Epoch 22/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9396 - dice_coefficient: 0.3727 - loss: 0.6366 - mean_io_u_2: 0.6163
# Epoch 22: val_dice_coefficient did not improve from 0.39513
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.9396 - dice_coefficient: 0.3728 - loss: 0.6365 - mean_io_u_2: 0.6160 - val_accuracy: 0.8793 - val_dice_coefficient: 0.3431 - val_loss: 0.6660 - val_mean_io_u_2: 0.6143 - learning_rate: 1.0000e-04
# Epoch 23/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9408 - dice_coefficient: 0.3748 - loss: 0.6341 - mean_io_u_2: 0.6132
# Epoch 23: val_dice_coefficient did not improve from 0.39513
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.9408 - dice_coefficient: 0.3750 - loss: 0.6339 - mean_io_u_2: 0.6130 - val_accuracy: 0.9548 - val_dice_coefficient: 0.3782 - val_loss: 0.6317 - val_mean_io_u_2: 0.6784 - learning_rate: 1.0000e-04
# Epoch 24/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9434 - dice_coefficient: 0.4156 - loss: 0.5931 - mean_io_u_2: 0.6026
# Epoch 24: val_dice_coefficient did not improve from 0.39513
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.9434 - dice_coefficient: 0.4156 - loss: 0.5932 - mean_io_u_2: 0.6024 - val_accuracy: 0.9706 - val_dice_coefficient: 0.2958 - val_loss: 0.7129 - val_mean_io_u_2: 0.5399 - learning_rate: 1.0000e-04
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 19.
# [Train residual_se] Training completed.
# [Train residual_se] Final model saved as 'final_model_residual_se.keras'.

# %%
from tensorflow.keras.models import load_model

# Paths to the best models
model_paths = [
    "final_model_residual_spatial_dropout.keras",
    "final_model_residual_attention.keras",
    "final_model_residual_se.keras"
]

# Load the models
ensemble_models = []
for idx, path in enumerate(model_paths, 1):
    try:
        model = load_model(
            path,
            custom_objects={
                'dice_loss': dice_loss,
                'dice_coefficient': dice_coefficient
            }
        )
        ensemble_models.append(model)
        print(f"[Ensemble] Loaded Model {idx} from '{path}'.")
    except Exception as e:
        print(f"[Ensemble] Error loading Model {idx} from '{path}': {e}")
# Out:
# c:\Users\andri\miniconda3\envs\segmentation\lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 182 variables whereas the saved optimizer has 186 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# [Ensemble] Loaded Model 1 from 'final_model_residual_spatial_dropout.keras'.
# c:\Users\andri\miniconda3\envs\segmentation\lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 194 variables whereas the saved optimizer has 198 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# [Ensemble] Loaded Model 2 from 'final_model_residual_attention.keras'.
# [Ensemble] Loaded Model 3 from 'final_model_residual_se.keras'.
# c:\Users\andri\miniconda3\envs\segmentation\lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 210 variables whereas the saved optimizer has 214 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import numpy as np

def visualize_batch_2d(images, masks, predictions=None, num_samples=2):
    """
    Visualizes samples from a batch of 2D images and masks, and optionally predictions.

    Args:
        images (np.ndarray): Batch of images with shape (batch_size, height, width, 1).
        masks (np.ndarray): Batch of masks with shape (batch_size, height, width, 1).
        predictions (np.ndarray, optional): Batch of predicted masks with the same shape as masks.
        num_samples (int): Number of samples to visualize from the batch.
    """
    batch_size = images.shape[0]
    num_samples = min(num_samples, batch_size)
    
    for i in range(num_samples):
        image = images[i, :, :, 0]  # Shape: (height, width)
        mask = masks[i, :, :, 0]    # Shape: (height, width)
        if predictions is not None:
            pred = predictions[i, :, :, 0]  # Shape: (height, width)

        # Select the center slice (for 2D, this is the only slice)

        # Create a figure with subplots
        if predictions is not None:
            num_plots = 4  # MRI, Ground Truth, Prediction, Overlay, Difference
        else:
            num_plots = 2  # MRI and Ground Truth

        plt.figure(figsize=(24, 6))

        # MRI Image
        plt.subplot(1, num_plots, 1)
        plt.imshow(image, cmap='gray')
        plt.title(f'Sample {i+1} - MRI Image')
        plt.axis('off')

        # Ground Truth Mask
        plt.subplot(1, num_plots, 2)
        plt.imshow(mask, cmap='gray')
        plt.title(f'Sample {i+1} - Ground Truth')
        plt.axis('off')

        if predictions is not None:
            # Predicted Mask
            plt.subplot(1, num_plots, 3)
            plt.imshow(pred, cmap='gray')
            plt.title(f'Sample {i+1} - Prediction')
            plt.axis('off')

            # Overlay of Prediction on MRI
            plt.subplot(1, num_plots, 4)
            plt.imshow(image, cmap='gray')
            plt.imshow(pred, cmap='jet', alpha=0.5)
            plt.title(f'Sample {i+1} - Prediction Overlay')
            plt.axis('off')

        plt.tight_layout()
        plt.show()


def ensemble_predict(models, images):
    """
    Generates ensemble predictions by averaging the outputs of multiple models.
    
    Args:
        models (list): List of trained tf.keras.Model instances.
        images (np.ndarray): Batch of images to predict with shape (batch_size, height, width, channels).
    
    Returns:
        np.ndarray: Averaged predictions with shape (batch_size, height, width, 1).
    """
    # Collect predictions from each model
    predictions = [model.predict(images) for model in models]
    print(f"[Ensemble] Collected predictions from {len(models)} models.")
    
    # Compute the average of predictions
    avg_prediction = np.mean(predictions, axis=0)
    print(f"[Ensemble] Averaged predictions shape: {avg_prediction.shape}")
    
    return avg_prediction

def evaluate_ensemble(models, val_generator, validation_steps):
    """
    Evaluates the ensemble of models on the validation set.
    
    Args:
        models (list): List of trained tf.keras.Model instances.
        val_generator (generator): Validation data generator.
        validation_steps (int): Number of validation steps.
    
    Returns:
        dict: Aggregated evaluation metrics.
    """
    all_metrics = {
        'dice_coefficient': [],
        'accuracy': [],
        'mean_iou': []
    }
    
    print("[Ensemble Evaluation] Starting evaluation on validation set...")
    
    for step in range(validation_steps):
        print(f"\n[Ensemble Evaluation] Processing step {step + 1}/{validation_steps}...")
        images, masks = next(val_generator)
        print(f"[Ensemble Evaluation] Batch shapes - Images: {images.shape}, Masks: {masks.shape}")
        
        # Generate ensemble predictions
        preds = ensemble_predict(models, images)
        preds_binary = (preds > 0.5).astype(np.float32)
        print(f"[Ensemble Evaluation] Predictions thresholded to binary masks.")
        
        # Calculate metrics
        dice = dice_coefficient(masks, preds_binary).numpy()
        acc = tf.keras.metrics.binary_accuracy(masks, preds_binary).numpy().mean()
        miou_metric = MeanIoU(num_classes=2)
        miou_metric.update_state(masks, preds_binary)
        miou = miou_metric.result().numpy()
        
        # Append metrics
        all_metrics['dice_coefficient'].append(dice)
        all_metrics['accuracy'].append(acc)
        all_metrics['mean_iou'].append(miou)
        
        print(f"[Ensemble Evaluation] Dice Coefficient: {dice:.4f}, Accuracy: {acc:.4f}, Mean IoU: {miou:.4f}")
    
    # Calculate average metrics
    avg_metrics = {metric: np.mean(values) for metric, values in all_metrics.items()}
    print("\n[Ensemble Evaluation] Average Metrics:")
    for metric, value in avg_metrics.items():
        print(f"[Ensemble Evaluation] {metric}: {value:.4f}")
    
    return avg_metrics

def visualize_ensemble_predictions(models, val_generator, num_batches=2, num_samples=2):
    """
    Visualizes ensemble predictions on the validation set.
    
    Args:
        models (list): List of trained tf.keras.Model instances.
        val_generator (generator): Validation data generator.
        num_batches (int): Number of batches to visualize.
        num_samples (int): Number of samples per batch to visualize.
    """
    print("[Ensemble Visualization] Starting visualization of ensemble predictions...")
    
    for batch_num in range(num_batches):
        print(f"\n[Ensemble Visualization] Processing batch {batch_num + 1}/{num_batches}...")
        images, masks = next(val_generator)
        print(f"[Ensemble Visualization] Batch shapes - Images: {images.shape}, Masks: {masks.shape}")
        
        # Generate ensemble predictions
        preds = ensemble_predict(models, images)
        preds_binary = (preds > 0.5).astype(np.float32)
        print("[Ensemble Visualization] Predictions thresholded to binary masks.")
        
        # Visualize
        visualize_batch_2d(images, masks, predictions=preds_binary, num_samples=num_samples)

# %%
validation_steps = 10

val_generator = dataset_generator_2d(
        data_dir=data_dir,
        batch_size=batch_size,
        patch_size=patch_size,
        dataset_type="test",
        augmentations=None,
        prostatex_data=(prostatex_images, prostatex_masks)
    )

# Evaluate the ensemble
ensemble_metrics = evaluate_ensemble(ensemble_models, val_generator, validation_steps)
print("\n[Final Ensemble Evaluation Metrics]", ensemble_metrics)

# Visualize ensemble predictions
visualize_ensemble_predictions(ensemble_models, val_generator, num_batches=2, num_samples=2)
# Out:
# [Ensemble Evaluation] Starting evaluation on validation set...
#
# [Ensemble Evaluation] Processing step 1/10...
# [Ensemble Evaluation] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Evaluation] Predictions thresholded to binary masks.
# [Ensemble Evaluation] Dice Coefficient: 0.7276, Accuracy: 0.9646, Mean IoU: 0.7673
#
# [Ensemble Evaluation] Processing step 2/10...
# [Ensemble Evaluation] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Evaluation] Predictions thresholded to binary masks.
# [Ensemble Evaluation] Dice Coefficient: 0.7203, Accuracy: 0.9478, Mean IoU: 0.7535
#
# [Ensemble Evaluation] Processing step 3/10...
# [Ensemble Evaluation] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Evaluation] Predictions thresholded to binary masks.
# [Ensemble Evaluation] Dice Coefficient: 0.6359, Accuracy: 0.9788, Mean IoU: 0.7223
#
# [Ensemble Evaluation] Processing step 4/10...
# [Ensemble Evaluation] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Evaluation] Predictions thresholded to binary masks.
# [Ensemble Evaluation] Dice Coefficient: 0.7553, Accuracy: 0.9585, Mean IoU: 0.7812
#
# [Ensemble Evaluation] Processing step 5/10...
# [Ensemble Evaluation] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Evaluation] Predictions thresholded to binary masks.
# [Ensemble Evaluation] Dice Coefficient: 0.3806, Accuracy: 0.9707, Mean IoU: 0.6027
#
# [Ensemble Evaluation] Processing step 6/10...
# [Ensemble Evaluation] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Evaluation] Predictions thresholded to binary masks.
# [Ensemble Evaluation] Dice Coefficient: 0.7290, Accuracy: 0.9477, Mean IoU: 0.7586
#
# [Ensemble Evaluation] Processing step 7/10...
# [Ensemble Evaluation] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Evaluation] Predictions thresholded to binary masks.
# [Ensemble Evaluation] Dice Coefficient: 0.6711, Accuracy: 0.9806, Mean IoU: 0.7426
#
# [Ensemble Evaluation] Processing step 8/10...
# [Ensemble Evaluation] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Evaluation] Predictions thresholded to binary masks.
# [Ensemble Evaluation] Dice Coefficient: 0.7978, Accuracy: 0.9592, Mean IoU: 0.8096
#
# [Ensemble Evaluation] Processing step 9/10...
# [Ensemble Evaluation] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Evaluation] Predictions thresholded to binary masks.
# [Ensemble Evaluation] Dice Coefficient: 0.7289, Accuracy: 0.9566, Mean IoU: 0.7637
#
# [Ensemble Evaluation] Processing step 10/10...
# [Ensemble Evaluation] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Evaluation] Predictions thresholded to binary masks.
# [Ensemble Evaluation] Dice Coefficient: 0.7205, Accuracy: 0.9737, Mean IoU: 0.7680
#
# [Ensemble Evaluation] Average Metrics:
# [Ensemble Evaluation] dice_coefficient: 0.6867
# [Ensemble Evaluation] accuracy: 0.9638
# [Ensemble Evaluation] mean_iou: 0.7470
#
# [Final Ensemble Evaluation Metrics] {'dice_coefficient': 0.68670356, 'accuracy': 0.96381533, 'mean_iou': 0.74695355}
# [Ensemble Visualization] Starting visualization of ensemble predictions...
#
# [Ensemble Visualization] Processing batch 1/2...
# [Ensemble Visualization] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Visualization] Predictions thresholded to binary masks.
# [Ensemble Visualization] Processing batch 2/2...
# [Ensemble Visualization] Batch shapes - Images: (32, 128, 128, 1), Masks: (32, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# [Ensemble] Collected predictions from 3 models.
# [Ensemble] Averaged predictions shape: (32, 128, 128, 1)
# [Ensemble Visualization] Predictions thresholded to binary masks.
